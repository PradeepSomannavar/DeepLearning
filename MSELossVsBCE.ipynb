# %%
import torch
import torch.nn as nn

criterion = nn.MSELoss()

y_pred = torch.tensor([0.9])
y_true = torch.tensor([0], dtype=torch.float)

loss = criterion(y_pred, y_true)

print(f"MSE Loss: {loss.item():.2f}")
# Out:
# MSE Loss: 0.81

# %%
BCE Example Code

# %%
criterion = nn.BCELoss()

y_pred = torch.tensor([0.9])
y_true = torch.tensor([1], dtype=torch.float)

loss = criterion(y_pred, y_true)

print(f"Binary Cross Entropy Loss: {loss.item():.2f}")
# Out:
# Binary Cross Entropy Loss: 0.11
